# %% [markdown]
# # Exercise 8.1
# ## Sinus forecasting
# In this task, we will learn to implement RNNs in Keras.
# Therefore:
#  - Run the provided script and comment on the output.
#  - Vary the number and size of the LSTM layers and compare training time and stability of the performance.
#
# The goal of this task is to predict the next value of a sine function. This is a special case because the output of the network (the `y` value) should correponds to the next input `x` value.

# %%
import numpy as np
import matplotlib.pyplot as plt
from tensorflow import keras
layers = keras.layers

print(keras.__version__)
# Out:
# 3.14.1

# %% [markdown]
# ### Generation of data
# We start by creating a signal trace: `t = 0-100`, `f = sin(pi * t)`

# %%
N = 10000
t = np.linspace(0, 100, N)  # time steps
f = np.sin(np.pi * t)  # signal

# %% [markdown]
# Split into semi-redundant sub-sequences of `length = window_size + 1` and perform shuffle

# %%
window_size = 20
n = N - window_size - 1  # number of possible splits
print(f"generating {n} semi redundant sub-sequences with size {window_size+1}.")
data = np.stack([f[i: i + window_size + 1] for i in range(n)])
print(data.shape)
# Out:
# generating 9979 semi redundant sub-sequences with size 21.
# (9979, 21)

# %% [markdown]
# Finally, split the data into features. The `x` values are the first 20 data points of a sequence. The `y` value is the corresponding next value in the sequence.

# %%
X, y = np.split(data, [-1], axis=1)

# as always, another dimension is added to the input vector
# because the KERAS library also allows for multiple inputs per time step.
# In our case here, we have just one input value per time stamp.
X = X[..., np.newaxis]
print(X.shape)
print(y.shape)
print('Example:')
print('X =', X[0, :, 0])
print('y =', y[0, :])
# Out:
# (9979, 20, 1)
# (9979, 1)
# Example:
# X = [0.         0.0314139  0.06279679 0.0941177  0.1253457  0.15644998
#  0.18739983 0.21816471 0.24871423 0.27901826 0.30904688 0.33877044
#  0.36815961 0.39718538 0.42581909 0.45403249 0.48179773 0.50908739
#  0.53587454 0.56213275]
# y = [0.58783609]

# %% [markdown]
# ### Define and train RNN

# %%
z0 = layers.Input(shape=[None, 1])
z = layers.LSTM(16, return_sequences=True)(z0) #need to add return_sequences=True for adding more layers
# additonal varying layers
z = layers.LSTM(16, return_sequences=True)(z)
z = layers.LSTM(16)(z)
z = layers.Dense(1)(z)
model = keras.models.Model(inputs=z0, outputs=z)
print(model.summary())

model.compile(loss='mse', optimizer='adam')
# Out:
# Model: "functional_8"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ input_layer_12 (InputLayer)     │ (None, None, 1)        │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_18 (LSTM)                  │ (None, None, 16)       │         1,152 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_19 (LSTM)                  │ (None, None, 16)       │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ lstm_20 (LSTM)                  │ (None, 16)             │         2,112 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_8 (Dense)                 │ (None, 1)              │            17 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 5,393 (21.07 KB)
#  Trainable params: 5,393 (21.07 KB)
#  Non-trainable params: 0 (0.00 B)
# None

# %%
results = model.fit(X, y,
    epochs=60,
    batch_size=32,
    verbose=2,
    validation_split=0.1,
    callbacks=[
        keras.callbacks.ReduceLROnPlateau(factor=0.67, patience=3, verbose=1, min_lr=1E-5),
        keras.callbacks.EarlyStopping(patience=4, verbose=1)])
# Out:
# Epoch 1/60
# 281/281 - 4s - 13ms/step - loss: 0.0378 - val_loss: 5.5928e-04 - learning_rate: 0.0010
# Epoch 2/60
# 281/281 - 2s - 7ms/step - loss: 1.9487e-04 - val_loss: 6.4813e-05 - learning_rate: 0.0010
# Epoch 3/60
# 281/281 - 2s - 7ms/step - loss: 6.5780e-05 - val_loss: 1.2298e-04 - learning_rate: 0.0010
# Epoch 4/60
# 281/281 - 2s - 7ms/step - loss: 6.7322e-05 - val_loss: 3.7947e-05 - learning_rate: 0.0010
# Epoch 5/60
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 0.0006700000318232924.
# 281/281 - 2s - 7ms/step - loss: 3.9079e-05 - val_loss: 4.1021e-05 - learning_rate: 0.0010
# Epoch 6/60
# 281/281 - 2s - 7ms/step - loss: 2.8088e-05 - val_loss: 1.8459e-05 - learning_rate: 6.7000e-04
# Epoch 7/60
# 281/281 - 2s - 6ms/step - loss: 1.7765e-05 - val_loss: 2.6187e-05 - learning_rate: 6.7000e-04
# Epoch 8/60
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 0.0004489000252215192.
# 281/281 - 2s - 7ms/step - loss: 2.5317e-05 - val_loss: 8.7310e-06 - learning_rate: 6.7000e-04
# Epoch 9/60
# 281/281 - 2s - 6ms/step - loss: 1.5110e-05 - val_loss: 1.8775e-05 - learning_rate: 4.4890e-04
# Epoch 10/60
# 281/281 - 2s - 7ms/step - loss: 1.0914e-05 - val_loss: 9.9778e-06 - learning_rate: 4.4890e-04
# Epoch 11/60
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 0.0003007630087086.
# 281/281 - 2s - 7ms/step - loss: 9.1805e-06 - val_loss: 5.8382e-06 - learning_rate: 4.4890e-04
# Epoch 12/60
# 281/281 - 2s - 7ms/step - loss: 7.7715e-06 - val_loss: 7.5383e-06 - learning_rate: 3.0076e-04
# Epoch 13/60
# 281/281 - 2s - 7ms/step - loss: 6.2234e-06 - val_loss: 4.0155e-06 - learning_rate: 3.0076e-04
# Epoch 14/60
#
# Epoch 14: ReduceLROnPlateau reducing learning rate to 0.0002015112101798877.
# 281/281 - 2s - 7ms/step - loss: 6.2381e-06 - val_loss: 4.0262e-06 - learning_rate: 3.0076e-04
# Epoch 15/60
# 281/281 - 2s - 7ms/step - loss: 5.4811e-06 - val_loss: 3.0354e-06 - learning_rate: 2.0151e-04
# Epoch 16/60
# 281/281 - 2s - 7ms/step - loss: 4.9351e-06 - val_loss: 3.7849e-06 - learning_rate: 2.0151e-04
# Epoch 17/60
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 0.00013501251160050743.
# 281/281 - 2s - 7ms/step - loss: 3.9539e-06 - val_loss: 3.9809e-06 - learning_rate: 2.0151e-04
# Epoch 18/60
# 281/281 - 2s - 7ms/step - loss: 2.9703e-06 - val_loss: 3.2432e-06 - learning_rate: 1.3501e-04
# Epoch 19/60
# 281/281 - 2s - 6ms/step - loss: 3.1710e-06 - val_loss: 2.5656e-06 - learning_rate: 1.3501e-04
# Epoch 20/60
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 9.04583813098725e-05.
# 281/281 - 2s - 7ms/step - loss: 2.4897e-06 - val_loss: 2.2095e-06 - learning_rate: 1.3501e-04
# Epoch 21/60
# 281/281 - 2s - 7ms/step - loss: 1.9978e-06 - val_loss: 4.9588e-06 - learning_rate: 9.0458e-05
# Epoch 22/60
# 281/281 - 2s - 7ms/step - loss: 2.1122e-06 - val_loss: 1.3386e-06 - learning_rate: 9.0458e-05
# Epoch 23/60
#
# Epoch 23: ReduceLROnPlateau reducing learning rate to 6.060711421014276e-05.
# 281/281 - 2s - 6ms/step - loss: 1.9115e-06 - val_loss: 1.2665e-06 - learning_rate: 9.0458e-05
# Epoch 24/60
# 281/281 - 2s - 6ms/step - loss: 1.4698e-06 - val_loss: 1.6555e-06 - learning_rate: 6.0607e-05
# Epoch 25/60
# 281/281 - 2s - 7ms/step - loss: 1.5955e-06 - val_loss: 1.1623e-06 - learning_rate: 6.0607e-05
# Epoch 26/60
#
# Epoch 26: ReduceLROnPlateau reducing learning rate to 4.060676725202939e-05.
# 281/281 - 2s - 7ms/step - loss: 1.3947e-06 - val_loss: 1.0577e-06 - learning_rate: 6.0607e-05
# Epoch 27/60
# 281/281 - 2s - 7ms/step - loss: 1.1461e-06 - val_loss: 1.4430e-06 - learning_rate: 4.0607e-05
# Epoch 28/60
# 281/281 - 2s - 7ms/step - loss: 1.0737e-06 - val_loss: 8.7423e-07 - learning_rate: 4.0607e-05
# Epoch 29/60
#
# Epoch 29: ReduceLROnPlateau reducing learning rate to 2.720653359574499e-05.
# 281/281 - 2s - 6ms/step - loss: 1.1745e-06 - val_loss: 8.2752e-07 - learning_rate: 4.0607e-05
# Epoch 30/60
# 281/281 - 2s - 7ms/step - loss: 9.4171e-07 - val_loss: 8.2966e-07 - learning_rate: 2.7207e-05
# Epoch 31/60
# 281/281 - 2s - 7ms/step - loss: 8.4258e-07 - val_loss: 1.7400e-06 - learning_rate: 2.7207e-05
# Epoch 32/60
#
# Epoch 32: ReduceLROnPlateau reducing learning rate to 1.8228377484774683e-05.
# 281/281 - 2s - 7ms/step - loss: 7.8878e-07 - val_loss: 6.7386e-07 - learning_rate: 2.7207e-05
# Epoch 33/60
# 281/281 - 2s - 6ms/step - loss: 7.4209e-07 - val_loss: 1.1102e-06 - learning_rate: 1.8228e-05
# Epoch 34/60
# 281/281 - 2s - 6ms/step - loss: 7.2149e-07 - val_loss: 8.1567e-07 - learning_rate: 1.8228e-05
# Epoch 35/60
#
# Epoch 35: ReduceLROnPlateau reducing learning rate to 1.2213012305437588e-05.
# 281/281 - 2s - 7ms/step - loss: 6.8244e-07 - val_loss: 5.6328e-07 - learning_rate: 1.8228e-05
# Epoch 36/60
# 281/281 - 2s - 7ms/step - loss: 6.5826e-07 - val_loss: 5.8851e-07 - learning_rate: 1.2213e-05
# Epoch 37/60
# 281/281 - 2s - 7ms/step - loss: 6.1604e-07 - val_loss: 5.4369e-07 - learning_rate: 1.2213e-05
# Epoch 38/60
#
# Epoch 38: ReduceLROnPlateau reducing learning rate to 1e-05.
# 281/281 - 2s - 7ms/step - loss: 5.8932e-07 - val_loss: 5.4030e-07 - learning_rate: 1.2213e-05
# Epoch 39/60
# 281/281 - 2s - 7ms/step - loss: 5.4872e-07 - val_loss: 5.1555e-07 - learning_rate: 1.0000e-05
# Epoch 40/60
# 281/281 - 2s - 7ms/step - loss: 5.3666e-07 - val_loss: 6.2258e-07 - learning_rate: 1.0000e-05
# Epoch 41/60
# 281/281 - 2s - 6ms/step - loss: 5.1705e-07 - val_loss: 4.5214e-07 - learning_rate: 1.0000e-05
# Epoch 42/60
# 281/281 - 2s - 7ms/step - loss: 4.7504e-07 - val_loss: 4.2697e-07 - learning_rate: 1.0000e-05
# Epoch 43/60
# 281/281 - 2s - 6ms/step - loss: 4.8529e-07 - val_loss: 4.4350e-07 - learning_rate: 1.0000e-05
# Epoch 44/60
# 281/281 - 2s - 7ms/step - loss: 4.6727e-07 - val_loss: 4.1608e-07 - learning_rate: 1.0000e-05
# Epoch 45/60
# 281/281 - 2s - 6ms/step - loss: 4.6211e-07 - val_loss: 3.7909e-07 - learning_rate: 1.0000e-05
# Epoch 46/60
# 281/281 - 2s - 7ms/step - loss: 4.1945e-07 - val_loss: 3.5930e-07 - learning_rate: 1.0000e-05
# Epoch 47/60
# 281/281 - 2s - 7ms/step - loss: 4.1433e-07 - val_loss: 4.1191e-07 - learning_rate: 1.0000e-05
# Epoch 48/60
# 281/281 - 2s - 7ms/step - loss: 3.9841e-07 - val_loss: 4.1054e-07 - learning_rate: 1.0000e-05
# Epoch 49/60
# 281/281 - 2s - 7ms/step - loss: 3.7515e-07 - val_loss: 3.4305e-07 - learning_rate: 1.0000e-05
# Epoch 50/60
# 281/281 - 2s - 6ms/step - loss: 3.5215e-07 - val_loss: 2.9376e-07 - learning_rate: 1.0000e-05
# Epoch 51/60
# 281/281 - 2s - 6ms/step - loss: 3.2153e-07 - val_loss: 2.7069e-07 - learning_rate: 1.0000e-05
# Epoch 52/60
# 281/281 - 2s - 6ms/step - loss: 3.0224e-07 - val_loss: 3.8320e-07 - learning_rate: 1.0000e-05
# Epoch 53/60
# 281/281 - 2s - 7ms/step - loss: 3.0463e-07 - val_loss: 2.6700e-07 - learning_rate: 1.0000e-05
# Epoch 54/60
# 281/281 - 2s - 7ms/step - loss: 2.9371e-07 - val_loss: 2.9705e-07 - learning_rate: 1.0000e-05
# Epoch 55/60
# 281/281 - 2s - 7ms/step - loss: 2.8150e-07 - val_loss: 2.6473e-07 - learning_rate: 1.0000e-05
# Epoch 56/60
# 281/281 - 2s - 7ms/step - loss: 2.5989e-07 - val_loss: 2.2200e-07 - learning_rate: 1.0000e-05
# Epoch 57/60
# 281/281 - 2s - 7ms/step - loss: 2.4715e-07 - val_loss: 2.6925e-07 - learning_rate: 1.0000e-05
# Epoch 58/60
# 281/281 - 2s - 7ms/step - loss: 2.3754e-07 - val_loss: 2.0550e-07 - learning_rate: 1.0000e-05
# Epoch 59/60
# 281/281 - 2s - 6ms/step - loss: 2.2159e-07 - val_loss: 2.1557e-07 - learning_rate: 1.0000e-05
# Epoch 60/60
# 281/281 - 2s - 7ms/step - loss: 2.0739e-07 - val_loss: 1.8458e-07 - learning_rate: 1.0000e-05

# %%
plt.figure(1, (12, 4))
plt.subplot(1, 2, 1)
plt.plot(results.history['loss'])
plt.plot(results.history['val_loss'])
plt.ylabel('loss')
plt.yscale("log")
plt.xlabel('epoch')
plt.legend(['train', 'val'], loc='upper right')
plt.tight_layout()

# %% [markdown]
# The performance gives well by the loss convergent and the validation loss are going well

# %% [markdown]
# ### Evaluate the model
# Investigate the forecasting capabilities of the model.

# %%
def predict_next_k(model, window, k=10):
    """Predict next k steps for the given model and starting sequence """
    x = window[np.newaxis, :, np.newaxis]  # initial input
    y = np.zeros(k)
    for i in range(k):
        y[i] = model.predict(x, verbose=0)[0,0]
        # create the new input including the last prediction
        x = np.roll(x, -1, axis=1)  # shift all inputs 1 step to the left
        x[:, -1] = y[i]  # add latest prediction to end
    return y

# %%
def plot_prediction(i0=0, k=500):
    """ Predict and plot the next k steps for an input starting at i0 """
    y0 = f[i0: i0 + window_size]  # starting window (input)
    y1 = predict_next_k(model, y0, k)  # predict next k steps

    t0 = t[i0: i0 + window_size]
    t1 = t[i0 + window_size: i0 + window_size + k]

    plt.figure(figsize=(12, 4))
    plt.plot(t, f, label='data')
    plt.plot(t0, y0, color='C1', lw=3, label='prediction')
    plt.plot(t1, y1, color='C1', ls='--')
    plt.xlim(0, 10)
    plt.legend()
    plt.xlabel('$t$')
    plt.ylabel('$f(t)$')

# %%
#Keep showing the 16 nodes performance
plot_prediction(115)

# %%
#Keep showing the 8 nodes performance
plot_prediction(115)

# %%
#Keep showing the 32 nodes performance
plot_prediction(115)

# %%
#Keep showing the 3 layers 16 nodes performance
plot_prediction(115)

# %% [markdown]
# As you see the plot, the prediction is well fitted with the sine data for 500 steps

# %% [markdown]
# ### Training time with different network
#
# - 1 layer 16 nodes -> 36.9s
# - 1 layer 8 nodes  -> 36.5s  (opinion) better performance than 16 nodes
# - 1 layer 32 nodes -> 40.2s
# - 1 layer 128 nodes -> early stopping at epoch 32 -> overtraining?
#
# - 2 layers 16 nodes -> early stopping at epoch 31
# - 3 layers 16 nodes -> 1m52s

# %% [markdown]
# From varying the structure, with more layers and nodes give well performance with sine data but only consumed more training time. Some network give early stopping due to overtraining(?)
